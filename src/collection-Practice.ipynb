# %% [markdown]
# # Practice

# %%
import librarium

HOME = '../data/biblioteka-practice'
STORE = '../data/store-practice'

collection = librarium.Collection(home=HOME, store=STORE)
# Out:
# 🟢 Init Collection
# 🟢 Init Store
# 🟢 load_store_data
# 🟢 read_elements <librarium.Collection object at 0x1070f32d0>

# %% [markdown]
# # Upgrade and Save - Practice

# %%
collection.upgrade()
# Out:
# 🟢 upgrade <librarium.Collection object at 0x104e57890>
# 🔴 🎭   Start ! remove_ds_store_files
# 🔴 🎭  Ignored:  .DS_Store 024 🥨 Propaganda T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 002 🚀 Mathimatics T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 002 🚀 Mathimatics T/28 - Quantum T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 802 🦖 Ser. Cambridge Companion T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store .DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/1 🏂 Bright Personalities T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/.DS_Store
# 🔴 🎭  Ignored:  .DS_Store 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/.DS_Store
# 🏓 cand_data
# {
#     "nickname": "🔹5058f1af",
#     "type": "dir",
#     "path": "."
# }
# 🥎 ADD element.id -5058f1af
# 🏓 cand_data 001 🪲 Philosophy T
# {
#     "nickname": "001 🪲 Phil🔹aebc0605",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T"
# }
# 🥎 ADD element.id 001-phil-aebc0605
# 🏓 cand_data 0-text-1.txt
# {
#     "nickname": "001 🪲 Phil🔹0-text-1.t🔹06d8002d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/0-text-1.txt"
# }
# 🥎 ADD element.id 0-text-1-06d8002d
# 🏓 cand_data 0-text-Phil.txt
# {
#     "nickname": "001 🪲 Phil🔹0-text-Phi🔹264d6721",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/0-text-Phil.txt"
# }
# 🥎 ADD element.id 0-text-p-264d6721
# 🏓 cand_data 1 🏂 Bright Personalities T
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹ddbc26b3",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T"
# }
# 🥎 ADD element.id 1-bright-ddbc26b3
# 🏓 cand_data 1596 🕯 Dekart Rene T
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹0a0abf2e",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T"
# }
# 🥎 ADD element.id 1596-dek-0a0abf2e
# 🏓 cand_data DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹DekartR-Ra🔹349f3531",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf"
# }
# 🥎 ADD element.id dekartr--349f3531
# 🏓 cand_data dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹dekart_ren🔹15291125",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu"
# }
# 🥎 ADD element.id dekart-r-15291125
# 🏓 cand_data 1883 - Yaspers Karl T
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹554d1334",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T"
# }
# 🥎 ADD element.id 1883-yas-554d1334
# 🏓 cand_data Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers Ka🔹bde68414",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub"
# }
# 🥎 ADD element.id yaspers--bde68414
# 🏓 cand_data Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_FI🔹54b31762",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub"
# }
# 🥎 ADD element.id yaspers--54b31762
# 🏓 cand_data Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Fi🔹ae51f352",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub"
# }
# 🥎 ADD element.id yaspers--ae51f352
# 🏓 cand_data Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹009a69f3",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub"
# }
# 🥎 ADD element.id yaspers--009a69f3
# 🏓 cand_data Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹ac4f6add",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub"
# }
# 🥎 ADD element.id yaspers--ac4f6add
# 🏓 cand_data Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹f679b338",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub"
# }
# 🥎 ADD element.id yaspers--f679b338
# 🏓 cand_data Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹b88d6217",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub"
# }
# 🥎 ADD element.id yaspers--b88d6217
# 🏓 cand_data yaspers._velikie_filosofy._kniga_2.pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers._v🔹f103cfa0",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf"
# }
# 🥎 ADD element.id yaspers--f103cfa0
# 🏓 cand_data yaspers.epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers.ep🔹d6507591",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub"
# }
# 🥎 ADD element.id yaspers--d6507591
# 🏓 cand_data Введение в философию (Ясперс Карл.).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Введение в🔹0230325d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf"
# }
# 🥎 ADD element.id vvedenie-0230325d
# 🏓 cand_data Кант жизнь, труды, влияние (Карл Ясперс).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Кант жизнь🔹7890bbf6",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf"
# }
# 🥎 ADD element.id kant-zhi-7890bbf6
# 🏓 cand_data Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ницше Введ🔹b7036d2c",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf"
# }
# 🥎 ADD element.id nitsshe--b7036d2c
# 🏓 cand_data Разум и экзистенция (Ясперс Карл).djvu
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Разум и эк🔹0d36c37d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu"
# }
# 🥎 ADD element.id razum-i--0d36c37d
# 🏓 cand_data Три точки зрения на человеческое познание (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Три точки 🔹b4a6e272",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf"
# }
# 🥎 ADD element.id tri-toch-b4a6e272
# 🏓 cand_data Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ясперс о Н🔹6dbce3e8",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf"
# }
# 🥎 ADD element.id iaspers--6dbce3e8
# 🏓 cand_data 1902 - Popper Karl T
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹09a75299",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T"
# }
# 🥎 ADD element.id 1902-pop-09a75299
# 🏓 cand_data Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди -🔹d34d28e0",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu"
# }
# 🥎 ADD element.id vse-liud-d34d28e0
# 🏓 cand_data Все люди — философы (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди —🔹a313c39b",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf"
# }
# 🥎 ADD element.id vse-liud-a313c39b
# 🏓 cand_data Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Вся жизнь 🔹87cda869",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu"
# }
# 🥎 ADD element.id vsia-zhi-87cda869
# 🏓 cand_data Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Знание и п🔹d350074a",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf"
# }
# 🥎 ADD element.id znanie-i-d350074a
# 🏓 cand_data Логика и рост научного знания (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика и р🔹765e7d20",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf"
# }
# 🥎 ADD element.id logika-i-765e7d20
# 🏓 cand_data Логика научного исследования (Поппер К.).djvu
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика нау🔹532c744b",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu"
# }
# 🥎 ADD element.id logika-n-532c744b
# 🏓 cand_data Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹2c3bcb16",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf"
# }
# 🥎 ADD element.id otkrytoe-2c3bcb16
# 🏓 cand_data Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹f125cea7",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf"
# }
# 🥎 ADD element.id otkrytoe-f125cea7
# 🏓 cand_data Три точки зрения на человеческое познание (Карл Поппер).epub
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹5b1fbdf7",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub"
# }
# 🥎 ADD element.id tri-toch-5b1fbdf7
# 🏓 cand_data Три точки зрения на человеческое познание (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹a20e7587",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf"
# }
# 🥎 ADD element.id tri-toch-a20e7587
# 🏓 cand_data Эволюционная эпистемология (Карл Поппер).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Эволюционн🔹89eca26f",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf"
# }
# 🥎 ADD element.id evoliuts-89eca26f
# 🏓 cand_data 1931 - Kenny Anthony T
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹da5a5a25",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T"
# }
# 🥎 ADD element.id 1931-ken-da5a5a25
# 🏓 cand_data A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹A New Hist🔹386c18f9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf"
# }
# 🥎 ADD element.id a-new-hi-386c18f9
# 🏓 cand_data An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹9ab02b01",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf"
# }
# 🥎 ADD element.id an-illus-9ab02b01
# 🏓 cand_data An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹60e1e0b9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf"
# }
# 🥎 ADD element.id an-illus-60e1e0b9
# 🏓 cand_data Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Ancient Ph🔹f1fc5dcf",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf"
# }
# 🥎 ADD element.id ancient--f1fc5dcf
# 🏓 cand_data Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Philosophy🔹d40300d9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf"
# }
# 🥎 ADD element.id philosop-d40300d9
# 🏓 cand_data Wittgenstein (Sir Anthony Kenny).pdf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Wittgenste🔹1068db97",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf"
# }
# 🥎 ADD element.id wittgens-1068db97
# 🏓 cand_data 4 🔬 Scientific Philosophy T
# {
#     "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹d759f978",
#     "type": "dir",
#     "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T"
# }
# 🥎 ADD element.id 4-scient-d759f978
# 🏓 cand_data Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu
# {
#     "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹Искушение 🔹a0b346f3",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu"
# }
# 🥎 ADD element.id iskushen-a0b346f3
# 🏓 cand_data 002 🚀 Mathimatics T
# {
#     "nickname": "002 🚀 Math🔹ec2429a9",
#     "type": "dir",
#     "path": "002 🚀 Mathimatics T"
# }
# 🥎 ADD element.id 002-math-ec2429a9
# 🏓 cand_data 0-text-2-Math.txt
# {
#     "nickname": "002 🚀 Math🔹0-text-2-M🔹3a0bc8ae",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/0-text-2-Math.txt"
# }
# 🥎 ADD element.id 0-text-2-3a0bc8ae
# 🏓 cand_data 28 - Quantum T
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹61fbc79e",
#     "type": "dir",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T"
# }
# 🥎 ADD element.id 28-quant-61fbc79e
# 🏓 cand_data Heisenberg T
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹a4348038",
#     "type": "dir",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T"
# }
# 🥎 ADD element.id heisenbe-a4348038
# 🏓 cand_data Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Geyzenberg🔹00ee779d",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub"
# }
# 🥎 ADD element.id geyzenbe-00ee779d
# 🏓 cand_data Heisenberg_Physik_und_Philosophie.pdf
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Heisenberg🔹d5da0b03",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf"
# }
# 🥎 ADD element.id heisenbe-d5da0b03
# 🏓 cand_data Verner_Geyzenberg__Shagi_Za_Gorizont.djvu
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Verner_Gey🔹217c18f0",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu"
# }
# 🥎 ADD element.id verner-g-217c18f0
# 🏓 cand_data Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Гейзенбер🔹e5ac1771",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub"
# }
# 🥎 ADD element.id geizenbe-e5ac1771
# 🏓 cand_data VF2010Lipkin-arpht5tmw0o.pdf
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹VF2010Lipk🔹828f69b1",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf"
# }
# 🥎 ADD element.id vf2010li-828f69b1
# 🏓 cand_data Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf
# {
#     "nickname": "002 🚀 Math🔹Operator T🔹71de4f25",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf"
# }
# 🥎 ADD element.id operator-71de4f25
# 🏓 cand_data 024 🥨 Propaganda T
# {
#     "nickname": "024 🥨 Prop🔹56e9e0eb",
#     "type": "dir",
#     "path": "024 🥨 Propaganda T"
# }
# 🥎 ADD element.id 024-prop-56e9e0eb
# 🏓 cand_data Storytelling for Law... by Philip Meyer (z-lib.org).epub
# {
#     "nickname": "024 🥨 Prop🔹Storytelli🔹b22a74ba",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub"
# }
# 🥎 ADD element.id storytel-b22a74ba
# 🏓 cand_data Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf
# {
#     "nickname": "024 🥨 Prop🔹Путеводите🔹6839418f",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf"
# }
# 🥎 ADD element.id putevodi-6839418f
# 🏓 cand_data Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf
# {
#     "nickname": "024 🥨 Prop🔹Россия в э🔹172f0390",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf"
# }
# 🥎 ADD element.id rossiia--172f0390
# 🏓 cand_data Смерть экспертизы [litres] (Том Николс).fb2
# {
#     "nickname": "024 🥨 Prop🔹Смерть экс🔹7375b617",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2"
# }
# 🥎 ADD element.id smert-ek-7375b617
# 🏓 cand_data Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub
# {
#     "nickname": "024 🥨 Prop🔹Я манипули🔹d8a95901",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub"
# }
# 🥎 ADD element.id ia-manip-d8a95901
# 🏓 cand_data 1001 - Ignore T
# {
#     "nickname": "1001 - Ign🔹f0286431",
#     "type": "dir",
#     "path": "1001 - Ignore T"
# }
# 🥎 ADD element.id 1001-ign-f0286431
# 🏓 cand_data Exploring-philosophy.pdf
# {
#     "nickname": "1001 - Ign🔹Exploring-🔹97c07138",
#     "type": "file",
#     "path": "1001 - Ignore T/Exploring-philosophy.pdf"
# }
# 🥎 ADD element.id explorin-97c07138
# 🏓 cand_data chanyshev. nachalo filosofii.pdf
# {
#     "nickname": "1001 - Ign🔹chanyshev.🔹6ef764e3",
#     "type": "file",
#     "path": "1001 - Ignore T/chanyshev. nachalo filosofii.pdf"
# }
# 🥎 ADD element.id chanyshe-6ef764e3
# 🏓 cand_data x-ignore.txt
# {
#     "nickname": "1001 - Ign🔹x-ignore.t🔹d534040d",
#     "type": "file",
#     "path": "1001 - Ignore T/x-ignore.txt"
# }
# 🥎 ADD element.id x-ignore-d534040d
# 🏓 cand_data Связь философии с жизнью в последние.ddjvu.pdf
# {
#     "nickname": "1001 - Ign🔹Связь фило🔹db077c16",
#     "type": "file",
#     "path": "1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf"
# }
# 🥎 ADD element.id sviaz-fi-db077c16
# 🏓 cand_data 802 🦖 Ser. Cambridge Companion T
# {
#     "nickname": "802 🦖 Ser.🔹0e580ac8",
#     "type": "dir",
#     "path": "802 🦖 Ser. Cambridge Companion T"
# }
# 🥎 ADD element.id 802-ser--0e580ac8
# 🏓 cand_data add
# {
#     "nickname": "802 🦖 Ser.🔹add🔹69cf6759",
#     "type": "dir",
#     "path": "802 🦖 Ser. Cambridge Companion T/add"
# }
# 🥎 ADD element.id add-69cf6759
# 🏓 cand_data A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf
# {
#     "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹edb97cdb",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf"
# }
# 🥎 ADD element.id a-compan-edb97cdb
# 🏓 cand_data A Companion to Food in the Ancient Wo... (z-lib.org).pdf
# {
#     "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹54e94b1e",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf"
# }
# 🥎 ADD element.id a-compan-54e94b1e

# %% [markdown]
# # Save - Practice

# %%
collection.save()
# Out:
# 🟢 save <librarium.Collection object at 0x104e57890>

# %% [markdown]
# # Cover - Practice

# %%
import librariumBooksCovers as Covers

Covers.covers_full(collection)
# Out:
# 🟢 generate_covers <librarium.Collection object at 0x10798e610>
#
# 🌠‍ Gen Cover For element:  tri-toch-a20e7587
#
# 🌠‍ Gen Cover For element:  otkrytoe-2c3bcb16
#
# 🌠‍ Gen Cover For element:  yaspers--f679b338
#
# 🌠‍ Gen Cover For element:  28-quant-61fbc79e
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  geyzenbe-00ee779d
# 🔻 Error. get_epub_cover(
# 🔻Err - if not find_cover_image_path_in_epub:
#
# 🌠‍ Gen Cover For element:  heisenbe-a4348038
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  smert-ek-7375b617
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  a-compan-54e94b1e
#
# 🌠‍ Gen Cover For element:  vse-liud-a313c39b
#
# 🌠‍ Gen Cover For element:  wittgens-1068db97
#
# 🌠‍ Gen Cover For element:  otkrytoe-f125cea7
#
# 🌠‍ Gen Cover For element:  heisenbe-d5da0b03
#
# 🌠‍ Gen Cover For element:  yaspers--54b31762
#
# 🌠‍ Gen Cover For element:  yaspers--d6507591
#
# 🌠‍ Gen Cover For element:  tri-toch-b4a6e272
#
# 🌠‍ Gen Cover For element:  tri-toch-5b1fbdf7
# 🔻 Err. try:with zipfile.ZipFile(path.as_posix())
# 🔻Err - if not data_image:
#
# 🌠‍ Gen Cover For element:  1931-ken-da5a5a25
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  explorin-97c07138
#
# 🌠‍ Gen Cover For element:  logika-i-765e7d20
#
# 🌠‍ Gen Cover For element:  ia-manip-d8a95901
#
# 🌠‍ Gen Cover For element:  yaspers--ac4f6add
#
# 🌠‍ Gen Cover For element:  024-prop-56e9e0eb
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  verner-g-217c18f0
#
# 🌠‍ Gen Cover For element:  1001-ign-f0286431
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  storytel-b22a74ba
#
# 🌠‍ Gen Cover For element:  yaspers--009a69f3
# 🔻 Error. get_epub_cover(
# 🔻Err - if not find_cover_image_path_in_epub:
#
# 🌠‍ Gen Cover For element:  vvedenie-0230325d
#
# 🌠‍ Gen Cover For element:  logika-n-532c744b
#
# 🌠‍ Gen Cover For element:  sviaz-fi-db077c16
#
# 🌠‍ Gen Cover For element:  vse-liud-d34d28e0
#
# 🌠‍ Gen Cover For element:  chanyshe-6ef764e3
#
# 🌠‍ Gen Cover For element:  a-compan-edb97cdb
#
# 🌠‍ Gen Cover For element:  yaspers--ae51f352
#
# 🌠‍ Gen Cover For element:  002-math-ec2429a9
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  x-ignore-d534040d
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  add-69cf6759
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  an-illus-60e1e0b9
#
# 🌠‍ Gen Cover For element:  1883-yas-554d1334
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  a-new-hi-386c18f9
#
# 🌠‍ Gen Cover For element:  4-scient-d759f978
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  vsia-zhi-87cda869
#
# 🌠‍ Gen Cover For element:  yaspers--f103cfa0
#
# 🌠‍ Gen Cover For element:  0-text-2-3a0bc8ae
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  1-bright-ddbc26b3
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  operator-71de4f25
#
# 🌠‍ Gen Cover For element:  evoliuts-89eca26f
#
# 🌠‍ Gen Cover For element:  rossiia--172f0390
#
# 🌠‍ Gen Cover For element:  iskushen-a0b346f3
#
# 🌠‍ Gen Cover For element:  iaspers--6dbce3e8
#
# 🌠‍ Gen Cover For element:  001-phil-aebc0605
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  putevodi-6839418f
#
# 🌠‍ Gen Cover For element:  an-illus-9ab02b01
#
# 🌠‍ Gen Cover For element:  0-text-1-06d8002d
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  philosop-d40300d9
#
# 🌠‍ Gen Cover For element:  ancient--f1fc5dcf
#
# 🌠‍ Gen Cover For element:  geizenbe-e5ac1771
#
# 🌠‍ Gen Cover For element:  802-ser--0e580ac8
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  kant-zhi-7890bbf6
#
# 🌠‍ Gen Cover For element:  znanie-i-d350074a
#
# 🌠‍ Gen Cover For element:  vf2010li-828f69b1
#
# 🌠‍ Gen Cover For element:  razum-i--0d36c37d
#
# 🌠‍ Gen Cover For element:  1902-pop-09a75299
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  nitsshe--b7036d2c
#
# 🌠‍ Gen Cover For element:  dekart-r-15291125
#
# 🌠‍ Gen Cover For element:  yaspers--b88d6217
#
# 🌠‍ Gen Cover For element:  1596-dek-0a0abf2e
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  yaspers--bde68414
# 🔻 Error. get_epub_cover(
# 🔻Err - if not find_cover_image_path_in_epub:
#
# 🌠‍ Gen Cover For element:  -5058f1af
# 🔸Warn - Extension of your file is not supported
#
# 🌠‍ Gen Cover For element:  dekartr--349f3531
#
# 🌠‍ Gen Cover For element:  0-text-p-264d6721
# 🔸Warn - Extension of your file is not supported
# 🟢 save <librarium.Collection object at 0x10798e610>
# 🟢 save <librarium.Collection object at 0x10798e610>

# %% [markdown]
# # Export - Practice

# %%
import librariunExport as Export

Export.export_full(collection)
# Out:
# 🟢 export_full <librarium.Collection object at 0x1070f32d0>
# 🟢 export_elements_tree <librarium.Collection object at 0x1070f32d0>
# 🟢 export_elements <librarium.Collection object at 0x1070f32d0>
# 🟢 export_elements_months <librarium.Collection object at 0x1070f32d0>
# 🟢 export_elements_times <librarium.Collection object at 0x1070f32d0>

# %%
for id_, element in collection.elements.items():
    print(id_)
    print(element.home)
    print()
    print(element.home.resolve().joinpath(element.path.as_posix()))
    print(element.path.as_posix())
    print()
    print()
# Out:
# tri-toch-a20e7587
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
#
#
# otkrytoe-2c3bcb16
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf
#
#
# yaspers--f679b338
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub
#
#
# 28-quant-61fbc79e
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T
# 002 🚀 Mathimatics T/28 - Quantum T
#
#
# geyzenbe-00ee779d
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub
# 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub
#
#
# heisenbe-a4348038
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T
# 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T
#
#
# smert-ek-7375b617
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2
# 024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2
#
#
# a-compan-54e94b1e
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf
# 802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf
#
#
# vse-liud-a313c39b
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf
#
#
# wittgens-1068db97
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf
#
#
# otkrytoe-f125cea7
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf
#
#
# heisenbe-d5da0b03
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf
# 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf
#
#
# yaspers--54b31762
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub
#
#
# yaspers--d6507591
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub
#
#
# tri-toch-b4a6e272
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
#
#
# tri-toch-5b1fbdf7
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub
#
#
# 1931-ken-da5a5a25
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T
#
#
# explorin-97c07138
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/1001 - Ignore T/Exploring-philosophy.pdf
# 1001 - Ignore T/Exploring-philosophy.pdf
#
#
# logika-i-765e7d20
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf
#
#
# ia-manip-d8a95901
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub
# 024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub
#
#
# yaspers--ac4f6add
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub
#
#
# 024-prop-56e9e0eb
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T
# 024 🥨 Propaganda T
#
#
# verner-g-217c18f0
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu
# 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu
#
#
# 1001-ign-f0286431
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/1001 - Ignore T
# 1001 - Ignore T
#
#
# storytel-b22a74ba
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub
# 024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub
#
#
# yaspers--009a69f3
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub
#
#
# vvedenie-0230325d
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf
#
#
# logika-n-532c744b
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu
#
#
# sviaz-fi-db077c16
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf
# 1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf
#
#
# vse-liud-d34d28e0
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu
#
#
# chanyshe-6ef764e3
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/1001 - Ignore T/chanyshev. nachalo filosofii.pdf
# 1001 - Ignore T/chanyshev. nachalo filosofii.pdf
#
#
# a-compan-edb97cdb
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf
# 802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf
#
#
# yaspers--ae51f352
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub
#
#
# 002-math-ec2429a9
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T
# 002 🚀 Mathimatics T
#
#
# x-ignore-d534040d
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/1001 - Ignore T/x-ignore.txt
# 1001 - Ignore T/x-ignore.txt
#
#
# add-69cf6759
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add
# 802 🦖 Ser. Cambridge Companion T/add
#
#
# an-illus-60e1e0b9
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf
#
#
# 1883-yas-554d1334
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T
#
#
# a-new-hi-386c18f9
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf
#
#
# 4-scient-d759f978
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/4 🔬 Scientific Philosophy T
# 001 🪲 Philosophy T/4 🔬 Scientific Philosophy T
#
#
# vsia-zhi-87cda869
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu
#
#
# yaspers--f103cfa0
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf
#
#
# 0-text-2-3a0bc8ae
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/0-text-2-Math.txt
# 002 🚀 Mathimatics T/0-text-2-Math.txt
#
#
# 1-bright-ddbc26b3
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T
#
#
# operator-71de4f25
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf
# 002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf
#
#
# evoliuts-89eca26f
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf
#
#
# rossiia--172f0390
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf
# 024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf
#
#
# iskushen-a0b346f3
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu
# 001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu
#
#
# iaspers--6dbce3e8
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf
#
#
# 001-phil-aebc0605
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T
# 001 🪲 Philosophy T
#
#
# putevodi-6839418f
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf
# 024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf
#
#
# an-illus-9ab02b01
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf
#
#
# 0-text-1-06d8002d
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/0-text-1.txt
# 001 🪲 Philosophy T/0-text-1.txt
#
#
# philosop-d40300d9
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf
#
#
# ancient--f1fc5dcf
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf
#
#
# geizenbe-e5ac1771
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub
# 002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub
#
#
# 802-ser--0e580ac8
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/802 🦖 Ser. Cambridge Companion T
# 802 🦖 Ser. Cambridge Companion T
#
#
# kant-zhi-7890bbf6
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf
#
#
# znanie-i-d350074a
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf
#
#
# vf2010li-828f69b1
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf
# 002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf
#
#
# razum-i--0d36c37d
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu
#
#
# 1902-pop-09a75299
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T
#
#
# nitsshe--b7036d2c
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf
#
#
# dekart-r-15291125
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu
#
#
# yaspers--b88d6217
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub
#
#
# 1596-dek-0a0abf2e
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T
#
#
# yaspers--bde68414
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub
#
#
# -5058f1af
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice
# .
#
#
# dekartr--349f3531
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf
# 001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf
#
#
# 0-text-p-264d6721
# ../data/biblioteka-practice
#
# /Users/andrewlevin/Desktop/1-LIBRARIUM-PRIVATUS/data-librariumprivatus/biblioteka-practice/001 🪲 Philosophy T/0-text-Phil.txt
# 001 🪲 Philosophy T/0-text-Phil.txt

# %%
import librariunExport as Export

Export.export_full(collection)
# Out:
# 🛵 Export:  tri-toch-a20e7587
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹a20e7587",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf",
#     "cover": "tri-toch-a20e7587.jpg",
#     "cover_ratio": 1.419
# }
#
# 🛵 Export:  otkrytoe-2c3bcb16
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹2c3bcb16",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf",
#     "cover": "otkrytoe-2c3bcb16.jpg",
#     "cover_ratio": 1.414
# }
#
# 🛵 Export:  yaspers--f679b338
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹f679b338",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub",
#     "cover": "yaspers--f679b338.jpg",
#     "cover_ratio": 1.643
# }
#
# 🛵 Export:  28-quant-61fbc79e
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹61fbc79e",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T"
# }
#
# 🛵 Export:  geyzenbe-00ee779d
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Geyzenberg🔹00ee779d",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub"
# }
#
# 🛵 Export:  heisenbe-a4348038
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹a4348038",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T"
# }
#
# 🛵 Export:  smert-ek-7375b617
# {
#     "nickname": "024 🥨 Prop🔹Смерть экс🔹7375b617",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2"
# }
#
# 🛵 Export:  a-compan-54e94b1e
# {
#     "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹54e94b1e",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf",
#     "cover": "a-compan-54e94b1e.jpg",
#     "cover_ratio": 1.435
# }
#
# 🛵 Export:  vse-liud-a313c39b
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди —🔹a313c39b",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf",
#     "cover": "vse-liud-a313c39b.jpg",
#     "cover_ratio": 1.545
# }
#
# 🛵 Export:  wittgens-1068db97
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Wittgenste🔹1068db97",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf",
#     "cover": "wittgens-1068db97.jpg",
#     "cover_ratio": 1.427
# }
#
# 🛵 Export:  otkrytoe-f125cea7
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹f125cea7",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf",
#     "cover": "otkrytoe-f125cea7.jpg",
#     "cover_ratio": 1.414
# }
#
# 🛵 Export:  heisenbe-d5da0b03
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Heisenberg🔹d5da0b03",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf",
#     "cover": "heisenbe-d5da0b03.jpg",
#     "cover_ratio": 1.493
# }
#
# 🛵 Export:  yaspers--54b31762
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_FI🔹54b31762",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub",
#     "cover": "yaspers--54b31762.jpg",
#     "cover_ratio": 1.321
# }
#
# 🛵 Export:  yaspers--d6507591
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers.ep🔹d6507591",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub",
#     "cover": "yaspers--d6507591.jpg",
#     "cover_ratio": 1.333
# }
#
# 🛵 Export:  tri-toch-b4a6e272
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Три точки 🔹b4a6e272",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf",
#     "cover": "tri-toch-b4a6e272.jpg",
#     "cover_ratio": 1.419
# }
#
# 🛵 Export:  tri-toch-5b1fbdf7
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹5b1fbdf7",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub"
# }
#
# 🛵 Export:  1931-ken-da5a5a25
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹da5a5a25",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T"
# }
#
# 🛵 Export:  explorin-97c07138
# {
#     "nickname": "1001 - Ign🔹Exploring-🔹97c07138",
#     "type": "file",
#     "path": "1001 - Ignore T/Exploring-philosophy.pdf",
#     "cover": "explorin-97c07138.jpg",
#     "cover_ratio": 1.428
# }
#
# 🛵 Export:  logika-i-765e7d20
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика и р🔹765e7d20",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf",
#     "cover": "logika-i-765e7d20.jpg",
#     "cover_ratio": 0.789
# }
#
# 🛵 Export:  ia-manip-d8a95901
# {
#     "nickname": "024 🥨 Prop🔹Я манипули🔹d8a95901",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub",
#     "cover": "ia-manip-d8a95901.jpg",
#     "cover_ratio": 1.5
# }
#
# 🛵 Export:  yaspers--ac4f6add
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹ac4f6add",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub",
#     "cover": "yaspers--ac4f6add.jpg",
#     "cover_ratio": 1.49
# }
#
# 🛵 Export:  024-prop-56e9e0eb
# {
#     "nickname": "024 🥨 Prop🔹56e9e0eb",
#     "type": "file",
#     "path": "024 🥨 Propaganda T"
# }
#
# 🛵 Export:  verner-g-217c18f0
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Verner_Gey🔹217c18f0",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu",
#     "cover": "verner-g-217c18f0.jpg"
# }
#
# 🛵 Export:  1001-ign-f0286431
# {
#     "nickname": "1001 - Ign🔹f0286431",
#     "type": "file",
#     "path": "1001 - Ignore T"
# }
#
# 🛵 Export:  storytel-b22a74ba
# {
#     "nickname": "024 🥨 Prop🔹Storytelli🔹b22a74ba",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub",
#     "cover": "storytel-b22a74ba.jpg",
#     "cover_ratio": 1.511
# }
#
# 🛵 Export:  yaspers--009a69f3
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹009a69f3",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub"
# }
#
# 🛵 Export:  vvedenie-0230325d
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Введение в🔹0230325d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf",
#     "cover": "vvedenie-0230325d.jpg",
#     "cover_ratio": 1.597
# }
#
# 🛵 Export:  logika-n-532c744b
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика нау🔹532c744b",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu",
#     "cover": "logika-n-532c744b.jpg"
# }
#
# 🛵 Export:  sviaz-fi-db077c16
# {
#     "nickname": "1001 - Ign🔹Связь фило🔹db077c16",
#     "type": "file",
#     "path": "1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf",
#     "cover": "sviaz-fi-db077c16.jpg",
#     "cover_ratio": 1.695
# }
#
# 🛵 Export:  vse-liud-d34d28e0
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди -🔹d34d28e0",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu",
#     "cover": "vse-liud-d34d28e0.jpg"
# }
#
# 🛵 Export:  chanyshe-6ef764e3
# {
#     "nickname": "1001 - Ign🔹chanyshev.🔹6ef764e3",
#     "type": "file",
#     "path": "1001 - Ignore T/chanyshev. nachalo filosofii.pdf",
#     "cover": "chanyshe-6ef764e3.jpg",
#     "cover_ratio": 1.575
# }
#
# 🛵 Export:  a-compan-edb97cdb
# {
#     "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹edb97cdb",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf",
#     "cover": "a-compan-edb97cdb.jpg",
#     "cover_ratio": 1.435
# }
#
# 🛵 Export:  yaspers--ae51f352
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Fi🔹ae51f352",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub",
#     "cover": "yaspers--ae51f352.jpg",
#     "cover_ratio": 1.529
# }
#
# 🛵 Export:  002-math-ec2429a9
# {
#     "nickname": "002 🚀 Math🔹ec2429a9",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T"
# }
#
# 🛵 Export:  x-ignore-d534040d
# {
#     "nickname": "1001 - Ign🔹x-ignore.t🔹d534040d",
#     "type": "file",
#     "path": "1001 - Ignore T/x-ignore.txt"
# }
#
# 🛵 Export:  add-69cf6759
# {
#     "nickname": "802 🦖 Ser.🔹add🔹69cf6759",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T/add"
# }
#
# 🛵 Export:  an-illus-60e1e0b9
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹60e1e0b9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf",
#     "cover": "an-illus-60e1e0b9.jpg",
#     "cover_ratio": 1.414
# }
#
# 🛵 Export:  1883-yas-554d1334
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹554d1334",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T"
# }
#
# 🛵 Export:  a-new-hi-386c18f9
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹A New Hist🔹386c18f9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf",
#     "cover": "a-new-hi-386c18f9.jpg",
#     "cover_ratio": 1.473
# }
#
# 🛵 Export:  4-scient-d759f978
# {
#     "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹d759f978",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T"
# }
#
# 🛵 Export:  vsia-zhi-87cda869
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Вся жизнь 🔹87cda869",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu",
#     "cover": "vsia-zhi-87cda869.jpg"
# }
#
# 🛵 Export:  yaspers--f103cfa0
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers._v🔹f103cfa0",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf",
#     "cover": "yaspers--f103cfa0.jpg",
#     "cover_ratio": 1.556
# }
#
# 🛵 Export:  0-text-2-3a0bc8ae
# {
#     "nickname": "002 🚀 Math🔹0-text-2-M🔹3a0bc8ae",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/0-text-2-Math.txt"
# }
#
# 🛵 Export:  1-bright-ddbc26b3
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹ddbc26b3",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T"
# }
#
# 🛵 Export:  operator-71de4f25
# {
#     "nickname": "002 🚀 Math🔹Operator T🔹71de4f25",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf",
#     "cover": "operator-71de4f25.jpg",
#     "cover_ratio": 1.554
# }
#
# 🛵 Export:  evoliuts-89eca26f
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Эволюционн🔹89eca26f",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf",
#     "cover": "evoliuts-89eca26f.jpg",
#     "cover_ratio": 1.419
# }
#
# 🛵 Export:  rossiia--172f0390
# {
#     "nickname": "024 🥨 Prop🔹Россия в э🔹172f0390",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf",
#     "cover": "rossiia--172f0390.jpg",
#     "cover_ratio": 1.294
# }
#
# 🛵 Export:  iskushen-a0b346f3
# {
#     "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹Искушение 🔹a0b346f3",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu",
#     "cover": "iskushen-a0b346f3.jpg"
# }
#
# 🛵 Export:  iaspers--6dbce3e8
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ясперс о Н🔹6dbce3e8",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf",
#     "cover": "iaspers--6dbce3e8.jpg",
#     "cover_ratio": 1.415
# }
#
# 🛵 Export:  001-phil-aebc0605
# {
#     "nickname": "001 🪲 Phil🔹aebc0605",
#     "type": "file",
#     "path": "001 🪲 Philosophy T"
# }
#
# 🛵 Export:  putevodi-6839418f
# {
#     "nickname": "024 🥨 Prop🔹Путеводите🔹6839418f",
#     "type": "file",
#     "path": "024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf",
#     "cover": "putevodi-6839418f.jpg",
#     "cover_ratio": 1.419
# }
#
# 🛵 Export:  an-illus-9ab02b01
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹9ab02b01",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf",
#     "cover": "an-illus-9ab02b01.jpg",
#     "cover_ratio": 1.441
# }
#
# 🛵 Export:  0-text-1-06d8002d
# {
#     "nickname": "001 🪲 Phil🔹0-text-1.t🔹06d8002d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/0-text-1.txt"
# }
#
# 🛵 Export:  philosop-d40300d9
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Philosophy🔹d40300d9",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf",
#     "cover": "philosop-d40300d9.jpg",
#     "cover_ratio": 1.511
# }
#
# 🛵 Export:  ancient--f1fc5dcf
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Ancient Ph🔹f1fc5dcf",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf",
#     "cover": "ancient--f1fc5dcf.jpg",
#     "cover_ratio": 1.51
# }
#
# 🛵 Export:  geizenbe-e5ac1771
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Гейзенбер🔹e5ac1771",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub",
#     "cover": "geizenbe-e5ac1771.jpg",
#     "cover_ratio": 1.612
# }
#
# 🛵 Export:  802-ser--0e580ac8
# {
#     "nickname": "802 🦖 Ser.🔹0e580ac8",
#     "type": "file",
#     "path": "802 🦖 Ser. Cambridge Companion T"
# }
#
# 🛵 Export:  kant-zhi-7890bbf6
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Кант жизнь🔹7890bbf6",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf",
#     "cover": "kant-zhi-7890bbf6.jpg",
#     "cover_ratio": 1.355
# }
#
# 🛵 Export:  znanie-i-d350074a
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Знание и п🔹d350074a",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf",
#     "cover": "znanie-i-d350074a.jpg",
#     "cover_ratio": 1.514
# }
#
# 🛵 Export:  vf2010li-828f69b1
# {
#     "nickname": "002 🚀 Math🔹28 - Quant🔹VF2010Lipk🔹828f69b1",
#     "type": "file",
#     "path": "002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf",
#     "cover": "vf2010li-828f69b1.jpg",
#     "cover_ratio": 1.433
# }
#
# 🛵 Export:  razum-i--0d36c37d
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Разум и эк🔹0d36c37d",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu",
#     "cover": "razum-i--0d36c37d.jpg"
# }
#
# 🛵 Export:  1902-pop-09a75299
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹09a75299",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T"
# }
#
# 🛵 Export:  nitsshe--b7036d2c
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ницше Введ🔹b7036d2c",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf",
#     "cover": "nitsshe--b7036d2c.jpg",
#     "cover_ratio": 1.415
# }
#
# 🛵 Export:  dekart-r-15291125
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹dekart_ren🔹15291125",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu",
#     "cover": "dekart-r-15291125.jpg"
# }
#
# 🛵 Export:  yaspers--b88d6217
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹b88d6217",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub",
#     "cover": "yaspers--b88d6217.jpg",
#     "cover_ratio": 1.637
# }
#
# 🛵 Export:  1596-dek-0a0abf2e
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹0a0abf2e",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T"
# }
#
# 🛵 Export:  yaspers--bde68414
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers Ka🔹bde68414",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub"
# }
#
# 🛵 Export:  -5058f1af
# {
#     "nickname": "🔹5058f1af",
#     "type": "dir",
#     "path": "."
# }
#
# 🛵 Export:  dekartr--349f3531
# {
#     "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹DekartR-Ra🔹349f3531",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf",
#     "cover": "dekartr--349f3531.jpg",
#     "cover_ratio": 1.414
# }
#
# 🛵 Export:  0-text-p-264d6721
# {
#     "nickname": "001 🪲 Phil🔹0-text-Phi🔹264d6721",
#     "type": "file",
#     "path": "001 🪲 Philosophy T/0-text-Phil.txt"
# }
#
# {
#     "tri-toch-a20e7587": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹a20e7587",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf",
#         "cover": "tri-toch-a20e7587.jpg",
#         "cover_ratio": 1.419
#     },
#     "otkrytoe-2c3bcb16": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹2c3bcb16",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf",
#         "cover": "otkrytoe-2c3bcb16.jpg",
#         "cover_ratio": 1.414
#     },
#     "yaspers--f679b338": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹f679b338",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub",
#         "cover": "yaspers--f679b338.jpg",
#         "cover_ratio": 1.643
#     },
#     "28-quant-61fbc79e": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹61fbc79e",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T"
#     },
#     "geyzenbe-00ee779d": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Geyzenberg🔹00ee779d",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub"
#     },
#     "heisenbe-a4348038": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹a4348038",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T"
#     },
#     "smert-ek-7375b617": {
#         "nickname": "024 🥨 Prop🔹Смерть экс🔹7375b617",
#         "type": "file",
#         "path": "024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2"
#     },
#     "a-compan-54e94b1e": {
#         "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹54e94b1e",
#         "type": "file",
#         "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf",
#         "cover": "a-compan-54e94b1e.jpg",
#         "cover_ratio": 1.435
#     },
#     "vse-liud-a313c39b": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди —🔹a313c39b",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf",
#         "cover": "vse-liud-a313c39b.jpg",
#         "cover_ratio": 1.545
#     },
#     "wittgens-1068db97": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Wittgenste🔹1068db97",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf",
#         "cover": "wittgens-1068db97.jpg",
#         "cover_ratio": 1.427
#     },
#     "otkrytoe-f125cea7": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Открытое о🔹f125cea7",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf",
#         "cover": "otkrytoe-f125cea7.jpg",
#         "cover_ratio": 1.414
#     },
#     "heisenbe-d5da0b03": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Heisenberg🔹d5da0b03",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf",
#         "cover": "heisenbe-d5da0b03.jpg",
#         "cover_ratio": 1.493
#     },
#     "yaspers--54b31762": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_FI🔹54b31762",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub",
#         "cover": "yaspers--54b31762.jpg",
#         "cover_ratio": 1.321
#     },
#     "yaspers--d6507591": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers.ep🔹d6507591",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub",
#         "cover": "yaspers--d6507591.jpg",
#         "cover_ratio": 1.333
#     },
#     "tri-toch-b4a6e272": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Три точки 🔹b4a6e272",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf",
#         "cover": "tri-toch-b4a6e272.jpg",
#         "cover_ratio": 1.419
#     },
#     "tri-toch-5b1fbdf7": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Три точки 🔹5b1fbdf7",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub"
#     },
#     "1931-ken-da5a5a25": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹da5a5a25",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T"
#     },
#     "explorin-97c07138": {
#         "nickname": "1001 - Ign🔹Exploring-🔹97c07138",
#         "type": "file",
#         "path": "1001 - Ignore T/Exploring-philosophy.pdf",
#         "cover": "explorin-97c07138.jpg",
#         "cover_ratio": 1.428
#     },
#     "logika-i-765e7d20": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика и р🔹765e7d20",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf",
#         "cover": "logika-i-765e7d20.jpg",
#         "cover_ratio": 0.789
#     },
#     "ia-manip-d8a95901": {
#         "nickname": "024 🥨 Prop🔹Я манипули🔹d8a95901",
#         "type": "file",
#         "path": "024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub",
#         "cover": "ia-manip-d8a95901.jpg",
#         "cover_ratio": 1.5
#     },
#     "yaspers--ac4f6add": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹ac4f6add",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub",
#         "cover": "yaspers--ac4f6add.jpg",
#         "cover_ratio": 1.49
#     },
#     "024-prop-56e9e0eb": {
#         "nickname": "024 🥨 Prop🔹56e9e0eb",
#         "type": "file",
#         "path": "024 🥨 Propaganda T"
#     },
#     "verner-g-217c18f0": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Verner_Gey🔹217c18f0",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu",
#         "cover": "verner-g-217c18f0.jpg"
#     },
#     "1001-ign-f0286431": {
#         "nickname": "1001 - Ign🔹f0286431",
#         "type": "file",
#         "path": "1001 - Ignore T"
#     },
#     "storytel-b22a74ba": {
#         "nickname": "024 🥨 Prop🔹Storytelli🔹b22a74ba",
#         "type": "file",
#         "path": "024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub",
#         "cover": "storytel-b22a74ba.jpg",
#         "cover_ratio": 1.511
#     },
#     "yaspers--009a69f3": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Sm🔹009a69f3",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub"
#     },
#     "vvedenie-0230325d": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Введение в🔹0230325d",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf",
#         "cover": "vvedenie-0230325d.jpg",
#         "cover_ratio": 1.597
#     },
#     "logika-n-532c744b": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Логика нау🔹532c744b",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu",
#         "cover": "logika-n-532c744b.jpg"
#     },
#     "sviaz-fi-db077c16": {
#         "nickname": "1001 - Ign🔹Связь фило🔹db077c16",
#         "type": "file",
#         "path": "1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf",
#         "cover": "sviaz-fi-db077c16.jpg",
#         "cover_ratio": 1.695
#     },
#     "vse-liud-d34d28e0": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Все люди -🔹d34d28e0",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu",
#         "cover": "vse-liud-d34d28e0.jpg"
#     },
#     "chanyshe-6ef764e3": {
#         "nickname": "1001 - Ign🔹chanyshev.🔹6ef764e3",
#         "type": "file",
#         "path": "1001 - Ignore T/chanyshev. nachalo filosofii.pdf",
#         "cover": "chanyshe-6ef764e3.jpg",
#         "cover_ratio": 1.575
#     },
#     "a-compan-edb97cdb": {
#         "nickname": "802 🦖 Ser.🔹add🔹A Companio🔹edb97cdb",
#         "type": "file",
#         "path": "802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf",
#         "cover": "a-compan-edb97cdb.jpg",
#         "cover_ratio": 1.435
#     },
#     "yaspers--ae51f352": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_Fi🔹ae51f352",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub",
#         "cover": "yaspers--ae51f352.jpg",
#         "cover_ratio": 1.529
#     },
#     "002-math-ec2429a9": {
#         "nickname": "002 🚀 Math🔹ec2429a9",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T"
#     },
#     "x-ignore-d534040d": {
#         "nickname": "1001 - Ign🔹x-ignore.t🔹d534040d",
#         "type": "file",
#         "path": "1001 - Ignore T/x-ignore.txt"
#     },
#     "add-69cf6759": {
#         "nickname": "802 🦖 Ser.🔹add🔹69cf6759",
#         "type": "file",
#         "path": "802 🦖 Ser. Cambridge Companion T/add"
#     },
#     "an-illus-60e1e0b9": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹60e1e0b9",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf",
#         "cover": "an-illus-60e1e0b9.jpg",
#         "cover_ratio": 1.414
#     },
#     "1883-yas-554d1334": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹554d1334",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T"
#     },
#     "a-new-hi-386c18f9": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹A New Hist🔹386c18f9",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf",
#         "cover": "a-new-hi-386c18f9.jpg",
#         "cover_ratio": 1.473
#     },
#     "4-scient-d759f978": {
#         "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹d759f978",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T"
#     },
#     "vsia-zhi-87cda869": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Вся жизнь 🔹87cda869",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu",
#         "cover": "vsia-zhi-87cda869.jpg"
#     },
#     "yaspers--f103cfa0": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹yaspers._v🔹f103cfa0",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf",
#         "cover": "yaspers--f103cfa0.jpg",
#         "cover_ratio": 1.556
#     },
#     "0-text-2-3a0bc8ae": {
#         "nickname": "002 🚀 Math🔹0-text-2-M🔹3a0bc8ae",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/0-text-2-Math.txt"
#     },
#     "1-bright-ddbc26b3": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹ddbc26b3",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T"
#     },
#     "operator-71de4f25": {
#         "nickname": "002 🚀 Math🔹Operator T🔹71de4f25",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf",
#         "cover": "operator-71de4f25.jpg",
#         "cover_ratio": 1.554
#     },
#     "evoliuts-89eca26f": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Эволюционн🔹89eca26f",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf",
#         "cover": "evoliuts-89eca26f.jpg",
#         "cover_ratio": 1.419
#     },
#     "rossiia--172f0390": {
#         "nickname": "024 🥨 Prop🔹Россия в э🔹172f0390",
#         "type": "file",
#         "path": "024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf",
#         "cover": "rossiia--172f0390.jpg",
#         "cover_ratio": 1.294
#     },
#     "iskushen-a0b346f3": {
#         "nickname": "001 🪲 Phil🔹4 🔬 Scient🔹Искушение 🔹a0b346f3",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu",
#         "cover": "iskushen-a0b346f3.jpg"
#     },
#     "iaspers--6dbce3e8": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ясперс о Н🔹6dbce3e8",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf",
#         "cover": "iaspers--6dbce3e8.jpg",
#         "cover_ratio": 1.415
#     },
#     "001-phil-aebc0605": {
#         "nickname": "001 🪲 Phil🔹aebc0605",
#         "type": "file",
#         "path": "001 🪲 Philosophy T"
#     },
#     "putevodi-6839418f": {
#         "nickname": "024 🥨 Prop🔹Путеводите🔹6839418f",
#         "type": "file",
#         "path": "024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf",
#         "cover": "putevodi-6839418f.jpg",
#         "cover_ratio": 1.419
#     },
#     "an-illus-9ab02b01": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹An Illustr🔹9ab02b01",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf",
#         "cover": "an-illus-9ab02b01.jpg",
#         "cover_ratio": 1.441
#     },
#     "0-text-1-06d8002d": {
#         "nickname": "001 🪲 Phil🔹0-text-1.t🔹06d8002d",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/0-text-1.txt"
#     },
#     "philosop-d40300d9": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Philosophy🔹d40300d9",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf",
#         "cover": "philosop-d40300d9.jpg",
#         "cover_ratio": 1.511
#     },
#     "ancient--f1fc5dcf": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1931 - Ken🔹Ancient Ph🔹f1fc5dcf",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf",
#         "cover": "ancient--f1fc5dcf.jpg",
#         "cover_ratio": 1.51
#     },
#     "geizenbe-e5ac1771": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹Heisenberg🔹Гейзенбер🔹e5ac1771",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub",
#         "cover": "geizenbe-e5ac1771.jpg",
#         "cover_ratio": 1.612
#     },
#     "802-ser--0e580ac8": {
#         "nickname": "802 🦖 Ser.🔹0e580ac8",
#         "type": "file",
#         "path": "802 🦖 Ser. Cambridge Companion T"
#     },
#     "kant-zhi-7890bbf6": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Кант жизнь🔹7890bbf6",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf",
#         "cover": "kant-zhi-7890bbf6.jpg",
#         "cover_ratio": 1.355
#     },
#     "znanie-i-d350074a": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹Знание и п🔹d350074a",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf",
#         "cover": "znanie-i-d350074a.jpg",
#         "cover_ratio": 1.514
#     },
#     "vf2010li-828f69b1": {
#         "nickname": "002 🚀 Math🔹28 - Quant🔹VF2010Lipk🔹828f69b1",
#         "type": "file",
#         "path": "002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf",
#         "cover": "vf2010li-828f69b1.jpg",
#         "cover_ratio": 1.433
#     },
#     "razum-i--0d36c37d": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Разум и эк🔹0d36c37d",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu",
#         "cover": "razum-i--0d36c37d.jpg"
#     },
#     "1902-pop-09a75299": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1902 - Pop🔹09a75299",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T"
#     },
#     "nitsshe--b7036d2c": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Ницше Введ🔹b7036d2c",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf",
#         "cover": "nitsshe--b7036d2c.jpg",
#         "cover_ratio": 1.415
#     },
#     "dekart-r-15291125": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹dekart_ren🔹15291125",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu",
#         "cover": "dekart-r-15291125.jpg"
#     },
#     "yaspers--b88d6217": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers_So🔹b88d6217",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub",
#         "cover": "yaspers--b88d6217.jpg",
#         "cover_ratio": 1.637
#     },
#     "1596-dek-0a0abf2e": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹0a0abf2e",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T"
#     },
#     "yaspers--bde68414": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1883 - Yas🔹Yaspers Ka🔹bde68414",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub"
#     },
#     "-5058f1af": {
#         "nickname": "🔹5058f1af",
#         "type": "dir",
#         "path": "."
#     },
#     "dekartr--349f3531": {
#         "nickname": "001 🪲 Phil🔹1 🏂 Bright🔹1596 🕯 Dek🔹DekartR-Ra🔹349f3531",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf",
#         "cover": "dekartr--349f3531.jpg",
#         "cover_ratio": 1.414
#     },
#     "0-text-p-264d6721": {
#         "nickname": "001 🪲 Phil🔹0-text-Phi🔹264d6721",
#         "type": "file",
#         "path": "001 🪲 Philosophy T/0-text-Phil.txt"
#     }
# }
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 1 Чары Платона (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-1.586039.fb2.epub
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Geyzenberg V.. Fizika i filosofiya - BooksCafe.Net.epub
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T
# 1677618000
#
# ../data/biblioteka-practice/024 🥨 Propaganda T/Смерть экспертизы [litres] (Том Николс).fb2
# 1677618000
#
# ../data/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди — философы (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Wittgenstein (Sir Anthony Kenny).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Открытое общество и его враги. Том 2 Время лжепророков Гегель, Маркс и другие оракулы (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Heisenberg_Physik_und_Philosophie.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_FILOSOFSKOE-ORIENTIROVANIE-V-MIRE_RuLit_Net_326195.epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers.epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Три точки зрения на человеческое познание (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Три точки зрения на человеческое познание (Карл Поппер).epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T
# 1677618000
#
# ../data/biblioteka-practice/1001 - Ignore T/Exploring-philosophy.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика и рост научного знания (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/024 🥨 Propaganda T/Я манипулирую тобой. Методы противодействия скрытому влиянию (Никита Юрьевич Непряхин).epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_sbornik__RuLit_Net_240196.epub
# 1677618000
#
# ../data/biblioteka-practice/024 🥨 Propaganda T
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Verner_Geyzenberg__Shagi_Za_Gorizont.djvu
# 1677618000
#
# ../data/biblioteka-practice/1001 - Ignore T
# 1680296400
#
# ../data/biblioteka-practice/024 🥨 Propaganda T/Storytelling for Law... by Philip Meyer (z-lib.org).epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Smyisl_i_naznachenie_istorii_RuLit_Net_215543.epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Введение в философию (Ясперс Карл.).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Логика научного исследования (Поппер К.).djvu
# 1677618000
#
# ../data/biblioteka-practice/1001 - Ignore T/Связь философии с жизнью в последние.ddjvu.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Все люди - философы. Как я понимаю философию (Поппер Карл.).djvu
# 1677618000
#
# ../data/biblioteka-practice/1001 - Ignore T/chanyshev. nachalo filosofii.pdf
# 1648760400
#
# ../data/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add/A Companion to Food in the Ancient Wo... (z-lib.org) copy-2.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Filosofiya-Kniga-tretya-Metafizika_RuLit_Net_326193.epub
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T
# 1680296400
#
# ../data/biblioteka-practice/1001 - Ignore T/x-ignore.txt
# 1677618000
#
# ../data/biblioteka-practice/802 🦖 Ser. Cambridge Companion T/add
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief... by Sir Anthony Kenny (z-lib.org).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/A New History of Western Philosophy,Volume 2 - Medieval Philosophy (Anthony Kenny).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/4 🔬 Scientific Philosophy T
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Вся жизнь — решение проблем. О познании, истории и политике. Ч. 2 Мысли об истории и политике (Поппер К.Р.).djvu
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/yaspers._velikie_filosofy._kniga_2.pdf
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/0-text-2-Math.txt
# 1680296400
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/Operator Theoretic Aspects of Ergodic Theory (Tanja Eisner, Bálint Farkas, Markus Haase etc.) (z-lib.org).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Эволюционная эпистемология (Карл Поппер).pdf
# 1677618000
#
# ../data/biblioteka-practice/024 🥨 Propaganda T/Россия в эпоху постправды. Здравый смысл против информационного шума (Андрей Андреевич Мовчан).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/4 🔬 Scientific Philosophy T/Искушение святого Коперника ненаучные корни научной революции (Дмитриев И.С.).djvu
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ясперс о Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T
# 1680296400
#
# ../data/biblioteka-practice/024 🥨 Propaganda T/Путеводитель по лжи Критическое мышление в эпоху постправды (Russian Edition) (Левитин, Дэниел­).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/An Illustrated Brief History of Western Philosophy (Sir Anthony Kenny).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/0-text-1.txt
# 1680296400
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Philosophy in the Modern World A New History of Western Philosophy (Anthony Kenny).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1931 - Kenny Anthony T/Ancient Philosophy A New History of Western Philosophy, Volume 1 (Anthony Kenny).pdf
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/Heisenberg T/Гейзенбер Вернер. Шаги за горизонт - royallib.com.epub
# 1677618000
#
# ../data/biblioteka-practice/802 🦖 Ser. Cambridge Companion T
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Кант жизнь, труды, влияние (Карл Ясперс).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T/Знание и психофизическая проблема В защиту взаимодействия (Поппер Карл.).pdf
# 1677618000
#
# ../data/biblioteka-practice/002 🚀 Mathimatics T/28 - Quantum T/VF2010Lipkin-arpht5tmw0o.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Разум и экзистенция (Ясперс Карл).djvu
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1902 - Popper Karl T
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Ницше Введение в понимание его философствования (Карл Ясперс).pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/dekart_rene_rassuzhdenie_o_metode_metafizicheskie_razmyshlen.djvu
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers_Sobranie-sochineniy-po-psihopatologii-V-dvuh-tomah-Tom-2.586040.fb2.epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1883 - Yaspers Karl T/Yaspers Karl. Vvedenie v filosofiyu - BooksCafe.Net.epub
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/1 🏂 Bright Personalities T/1596 🕯 Dekart Rene T/DekartR-Razmyshljaja-o-pervoj-filosofii-filosoff.org_.pdf
# 1677618000
#
# ../data/biblioteka-practice/001 🪲 Philosophy T/0-text-Phil.txt
# 1680296400
