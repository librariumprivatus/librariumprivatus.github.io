# %%
import librarium


HOME = '../data/biblioteka-main/'
STORE = '../data/store'

collection = librarium.Collection(home=HOME, store=STORE)
# Out:
# 🟢 Init Collection
# 🟢 Init Store
# 🟢 load_store_data
# 🟢 read_elements <librarium.Collection object at 0x108e0d950>
# 🧯 INIT 002 🚀 Mathimatics/15 - Philosophy. Mathimatics/Lectures on the Philosophy of Mathematics (Joel David Hamkins).pdf
# 👺 lectures-656e201b 002 🚀 Mathimatics/15 - Philosophy. Mathimatics/Lectures on the Philosophy of Mathematics (Joel David Hamkins).pdf
# 🧯 INIT down-23-feb-Polit/The Oxford Handbook of the History of Political Philosophy (George Klosko).pdf
# 👺 the-oxfo-a216f97d down-23-feb-Polit/The Oxford Handbook of the History of Political Philosophy (George Klosko).pdf
# 🧯 INIT 001 🪲 Philosophy/133 - Analitic Philosophy/Gryaznov A F red - Analiticheskaya filosofia Izbrannye texty djvu.ddjvu.pdf
# 👺 gryaznov-29297054 001 🪲 Philosophy/133 - Analitic Philosophy/Gryaznov A F red - Analiticheskaya filosofia Izbrannye texty djvu.ddjvu.pdf
# 🧯 INIT 802 🦖 Ser. Cambridge Companion/The Cambridge Compan. by Tom RickettsMichae.pdf
# ...

# %%
import utils


mon_file = collection.store.path.joinpath('jsons/books-months-grid.json')
print(mon_file)

mon = utils.read_json(mon_file)
# Out:
# ../data/store/jsons/books-months-grid.json

# %%
import utils




months = mon['months']

utils.print_tree(months)
# Out:
# {
#     "1651352400": [
#         "lectures-656e201b",
#         "philosop-8fd70e04",
#         "platon-s-7af64f6a",
#         "golubaia-77427874",
#         "beil-p-i-5aa37ce7",
#         "trubetsk-886865ff",
#         "an-illus-4d77024c",
#         "platon-a-a4b4c464",
#         "vse-liud-85cdd309",
#         "a-histor-5590e08d",
#         "gassendi-dec29764",
#         "russkie--1fd13689",
#         "berkli-d-f6d441b3",
#         "antologi-ec588a9d",
#         "10-4324--b753e2f5",
#         "chernysh-96bca03a",
#         "the-oxfo-4254c6b0",
#         "gegel-g--24f558f9",
#         "florensk-d5a13a83",
#         "kant-i-s-751b1dcb",
#         "the-oxfo-3d8ac796",
#         "bekon-f--6ad27cc2",
#         "oxford-l-2db9c007",
#         "aristote-caf24f1a",
#         "c-how-to-2eb22965",
#         "a-histor-1539ad42",
#         "angliisk-04bb331e",
#         "feierbak-60c11caf",
#         "sopostav-ee593ce6",
#         "kritik-d-16a767eb",
#         "antologi-94d8f303",
# ...

# %%
import collections


months_sorted = collections.OrderedDict(sorted(months.items(), reverse=True))

# months_sorted = sorted(months.items(), key=lambda x: x[0])

# %%
utils.print_tree(months_sorted)
# Out:
# {
#     "1680296400": [
#         "7-annals-cf1fdec7",
#         "1953-deu-7607c561",
#         "001-phil-734ae7f1",
#         "struktur-da602096"
#     ],
#     "1677618000": [
#         "the-oxfo-a216f97d",
#         "gryaznov-29297054",
#         "zachem-n-fcd14808",
#         "lorenzo--56bc3476",
#         "beskonec-fba0a40e",
#         "moia-tai-6ae022d3",
#         "porog-to-a29516f7",
#         "imagined-ab18b178",
#         "topologi-6cb87777",
#         "pushkins-7cf2d106",
#         "sobranie-98ba13b6",
#         "1935-bou-0a457ef8",
#         "iazyk-fi-7f83e68b",
#         "1724-kan-64536d8c",
#         "o-zhizni-c86cd1b7",
#         "vsia-zhi-c1107fe1",
#         "semiotik-c9f7d8e0",
#         "realnost-d8069c4f",
#         "kurs-nag-cfc2bbc0",
#         "phys-23--b536fe01",
#         "velichai-f477bd6f",
#         "vasilev--a2661018",
#         "fiziko-m-153fa4eb",
#         "iunyi-te-60b0a00d",
#         "papers-2c1b9f8c",
#         "nepreryv-fc1c9dd5",
# ...

# %%
d = {
    '5four': 'aaaa',
    '4five': 'aaaa',
    '3three': 'aaaa',
    '2two': 'aaaa',
    '1one': 'aaaa',
}
a = sorted(d.items(), key=lambda x: x[0])    
print(a)
# Out:
# [('1one', 'aaaa'), ('2two', 'aaaa'), ('3three', 'aaaa'), ('4five', 'aaaa'), ('5four', 'aaaa')]
